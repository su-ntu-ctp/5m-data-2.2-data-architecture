# %% [markdown]
# # Assignment

# %% [markdown]
# ## Brief

# %% [markdown]
# Write the Python codes for the following questions.

# %% [markdown]
# ## Instructions

# %% [markdown]
# Paste the answer as Python in the answer code section below each question.

# %%
import os
import redis
from dotenv import load_dotenv


load_dotenv()
REDIS_HOST = os.getenv("REDIS_HOST")
REDIS_PORT = os.getenv("REDIS_PORT")
REDIS_USERNAME = os.getenv("REDIS_USERNAME")
REDIS_PASSWORD = os.getenv("REDIS_PASSWORD")
# Load environment variables from .env file

r = redis.Redis(
    host=REDIS_HOST,
    port=REDIS_PORT,
    decode_responses=True,
    username=REDIS_USERNAME,
    password=REDIS_PASSWORD
)

success = r.set('foo', 'bar')
# True

result = r.get('foo')
print(result)
# >>> bar
# Out:
# bar

# %% [markdown]
# ### Question 1

# %% [markdown]
# Question: How would you create a new hash in Redis to store information about a person, with `john_doe` as the key and include the name (`John Doe`), age (`35`), and email address (`john@email.com`)?

# %%
import redis

r = redis.Redis(
    host='redis-18504.crce285.us-east-1-4.ec2.cloud.redislabs.com',
    port=18504,
    username='default',   # RedisLabs usually uses "default"
    password='GO3huHM9FU2v9GlukhzggGGgpqljM80n',
)

# Create a new hash for john_doe
r.hset("john_doe", mapping={
    "name": "John Doe",
    "age": 35,
    "email": "john@email.com"
})

# Verify by retrieving the hash
person = r.hgetall("john_doe")
print(person)
# Out:
# {b'name': b'John Doe', b'age': b'35', b'email': b'john@email.com'}

# %% [markdown]
# Answer:

# %% [markdown]
# ### Question 2

# %% [markdown]
# Question: Write Python code to list the first 10 objects (blob name) in the "gcp-public-data-landsat" bucket, along with their sizes.

# %%
from google.cloud import storage

client = storage.Client.create_anonymous_client()
bucket = client.get_bucket("gcp-public-data-landsat")

# %% [markdown]
# Answer:

# %%
# Answer Question 2 here
from google.cloud import storage

# Initialize the client
client = storage.Client()

# Reference the bucket
bucket = client.bucket("gcp-public-data-landsat")

# List the first 10 blobs
blobs = bucket.list_blobs(max_results=10)

# Print blob names and sizes
for blob in blobs:
    print(f"Name: {blob.name}, Size: {blob.size} bytes")
# Out:
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_ANG.txt, Size: 117255 bytes
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B1.TIF, Size: 75085385 bytes
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B10.TIF, Size: 40612836 bytes
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B11.TIF, Size: 39267654 bytes
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B2.TIF, Size: 76259448 bytes
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B3.TIF, Size: 76813565 bytes
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B4.TIF, Size: 78510140 bytes
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B5.TIF, Size: 80344717 bytes
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B6.TIF, Size: 76416634 bytes
# Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B7.TIF, Size: 73888286 bytes
